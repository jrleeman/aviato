# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing CartoPy
import cartopy.crs as ccrs

# import cartopy's collection of map features
import cartopy.feature as cfeat

# %%
# Make a new figure
fig = plt.figure(figsize=(10, 8))

# Make a new axis with the LCC projection
ax = fig.add_subplot(1, 1, 1, projection=ccrs.LambertConformal())

# Add variety of features
ax.add_feature(cfeat.LAND)
ax.add_feature(cfeat.OCEAN)
ax.add_feature(cfeat.COASTLINE)

# Can also supply matplotlib kwargs
ax.add_feature(cfeat.BORDERS, linestyle=':')
ax.add_feature(cfeat.LAKES, alpha=0.5)
ax.add_feature(cfeat.RIVERS)

# Set limits in lat/lon space
ax.set_extent([-120, -70, 20, 50])

# %%
# Grab state borders
state_borders = cfeat.NaturalEarthFeature(category='cultural',
    name='admin_1_states_provinces_lakes', scale='50m', facecolor='none') 
ax.add_feature(state_borders, linestyle="dotted", edgecolor='black')

# Show the updated figure
fig

# %%
# Make a new projection
proj = ccrs.Stereographic(central_longitude=-95, central_latitude=35)

# %%
# Set up a plot with map features
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(1, 1, 1, projection=proj)
ax.add_feature(state_borders, edgecolor='black')
ax.add_feature(cfeat.BORDERS)
ax.gridlines()
ax.set_extent([-109,-100,35,42])

# %%
# Plot a star where Boulder, CO is located
ax.scatter(-105.27, 40.01, transform=ccrs.PlateCarree(), 
           marker='*', s=400, c='y')

# Show the updated figure
fig
